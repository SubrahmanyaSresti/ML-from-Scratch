# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

sns.set_theme()

# %%
df= pd.read_csv("trips.csv",parse_dates=["pickup_datetime","dropoff_datetime"])
df.head()
# Out:
#                           medallion                      hack_license  \
# 0  4D24F4D8EF35878595044A52B098DFD2  EEF7A2EC022DA207C643827D661999EC
# 1  A49C37EB966E7B05E69523D1CB7BE303  CA63EB3459FD5D97D4434EAFDE224898
# 2  1E4B72A8E623888F53A9693C364AC05A  06545280CEF9EE7070FD95246E6479C8
# 3  F7E4E9439C46B8AD5B16AB9F1B3279D7  08E1CEA4851C1A6BC150CD26D6D42C00
# 4  A9DC75D59E0EA27E1ED328E8BE8CD828  94E1D7C28F66ED93BD4A90B74FAB7356
#
#   vendor_id  rate_code store_and_fwd_flag           pickup_datetime  \
# 0       VTS          1                NaN 2013-01-13 10:23:00+00:00
# 1       VTS          1                NaN 2013-01-13 04:52:00+00:00
# 2       VTS          1                NaN 2013-01-13 10:47:00+00:00
# 3       VTS          1                NaN 2013-01-13 11:14:00+00:00
# 4       VTS          1                NaN 2013-01-13 11:24:00+00:00
#
#            dropoff_datetime  passenger_count  trip_time_in_secs  \
# 0 2013-01-13 10:33:00+00:00                1                600
# ...

# %%
df.shape
# Out:
# (49999, 14)

# %%
df.dtypes
# Out:
# medallion                          object
# hack_license                       object
# vendor_id                          object
# rate_code                           int64
# store_and_fwd_flag                 object
# pickup_datetime       datetime64[ns, UTC]
# dropoff_datetime      datetime64[ns, UTC]
# passenger_count                     int64
# trip_time_in_secs                   int64
# trip_distance                     float64
# pickup_longitude                  float64
# pickup_latitude                   float64
# dropoff_longitude                 float64
# dropoff_latitude                  float64
# dtype: object

# %%
df.columns
# Out:
# Index(['medallion', 'hack_license', 'vendor_id', 'rate_code',
#        'store_and_fwd_flag', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'trip_time_in_secs', 'trip_distance',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude'],
#       dtype='object')

# %%
df= df.drop(columns=['medallion', 'hack_license', 'vendor_id', 'rate_code',
       'store_and_fwd_flag', 'pickup_datetime', 'dropoff_datetime'])

# %%
df.where("trip_time_in_secs">10000,9000)=9000

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=df,x="trip_time_in_secs",y='trip_distance',hue="passenger_count",size="passenger_count")
# Out:
# <Axes: xlabel='trip_time_in_secs', ylabel='trip_distance'>
